# %%
# 패키지 설치
# !pip install konlpy
# !pip install wordcloud
# !pip install pandas matplotlib
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from konlpy) (1.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from konlpy) (6.0.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.12/dist-packages (from konlpy) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from JPype1>=0.7.0->konlpy) (25.0)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# # **1. 데이터 전처리**
# * 추출한 텍스트 데이터를 바탕으로 전처리 하는 코드
# * 전체 학생 데이터에서 학과, 전형, 창체기록을 추출하여 하나의 텍스트 파일을 생성함
# * 생성한 텍스트 파일에서 키워드를 추출하여 csv 파일로 저장함

# %%
# 한글 폰트 설치 및 확인
# !apt-get update -qq
# !apt-get install -qq fonts-nanum
# !fc-list :lang=ko
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# /usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf: NanumSquareRound,나눔스퀘어라운드,NanumSquareRound Bold,나눔스퀘어라운드 Bold:style=Bold,Regular
# /usr/share/fonts/truetype/nanum/NanumGothicCodingBold.ttf: NanumGothicCoding,나눔고딕코딩:style=Bold
# /usr/share/fonts/truetype/nanum/NanumSquareRoundR.ttf: NanumSquareRound,나눔스퀘어라운드,NanumSquareRound Regular,나눔스퀘어라운드 Regular:style=Regular
# /usr/share/fonts/truetype/nanum/NanumSquareB.ttf: NanumSquare,나눔스퀘어,NanumSquare Bold,나눔스퀘어 Bold:style=Bold
# /usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf: NanumBarunGothic,나눔바른고딕:style=Regular
# /usr/share/fonts/truetype/nanum/NanumGothic.ttf: NanumGothic,나눔고딕:style=Regular
# /usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf: NanumGothicCoding,나눔고딕코딩:style=Regular
# /usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf: NanumBarunGothic,나눔바른고딕:style=Bold
# /usr/share/fonts/truetype/nanum/NanumGothicBold.ttf: NanumGothic,나눔고딕:style=Bold
# /usr/share/fonts/truetype/nanum/NanumSquareR.ttf: NanumSquare,나눔스퀘어:style=Regular
# /usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf: NanumMyeongjo,나눔명조:style=Regular
# /usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf: NanumMyeongjo,나눔명조:style=Bold

# %%
import zipfile
import os

zip_path = "/content/생기부_원본_수정_txt.zip"
extract_path = "/content/records"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

os.listdir(extract_path)
# Out:
# ['202110491_3학년_경제금융_윤도경_정시_censored.txt',
#  '202511291_1_자유전공학부(인문사회계열)_조은진_정시_censored.txt',
#  '201910689_4학년_글로벌경영학과_손민수_정시_censored.txt',
#  '202410723_2학년_컴퓨터과학과_이정원_수시_censored.txt',
#  '202510837_1_컴퓨터과학과_이정민_정시_censored.txt',
#  '202511391_1학년_자유전공(it계열)_윤성재_수시_censored.txt',
#  '202510790_1학년_컴퓨터과학과_김이준_수시_censored.txt',
#  '202110903_3_컴퓨터과학과_권준성_수시_censored.txt',
#  '202311093_1학년_컴퓨터과학과_유선웅_정시_censored.txt',
#  '202510808_1학년_컴퓨터과학과_박유우_수시_censored.txt',
#  '202410891_2학년_컴퓨터과학과_장윤하_수시_censored.txt',
#  '202211046_4_지능IoT융합_이서진_수시_censored.txt',
#  '202210931_1학년_컴퓨터과학과_손현석_정시_censored.txt',
#  '202315060_3학년_휴먼AI공학전공_서현승_정시_censored.txt',
#  '202511602_1_컴퓨터과학과_최준영_정시_censored.txt',
#  '202411431_2학년_지적재산권전공_강수민_수시_censored.txt',
#  '202211047_2_컴퓨터과학전공_이수빈_정시_censored.txt',
#  '202110975_3_컴퓨터과학전공_정인철_수시_censored.txt',
#  '202510855_1학년_컴퓨터과학과_최현준_수시_censored.txt',
#  '202511383_1학년_컴퓨터과학과_백민건_수시_censored.txt',
#  '201910936_3_컴퓨터과학과_김연수_정시_censored.txt',
#  '202215036_4학년_경영학부_김재형_편입_censored.txt',
#  '202410821_2_컴퓨터과학전공_권서윤_정시_censored.txt',
#  '202510806_1학년_컴퓨터과학과_박시연_정시_censored.txt',
#  '202511585_1_자율전공_김태훈_수시_censored.txt',
#  '202410822_2학년_컴퓨터과학과_김건규_정시_censored.txt',
#  '202215075_4학년_컴퓨터과학과_윤용선_편입_censored.txt',
#  '202210903_2_컴퓨터과학과_김용준_정시_censored.txt',
#  '202511389_1학년_컴퓨터과학과_양석현_수시_censored.txt',
#  '202310767_3_컴퓨터과학전공_강한별_수시_censored.txt',
#  '202315168_3_컴퓨터과학과_최은서_정시_censored.txt',
#  '202510817_1학년_컴퓨터과학과_성민규_수시_censored.txt',
#  '202510824_1학년_컴퓨터과학과_유다연_정시_censored.txt',
#  '202510839_1학년_컴퓨터과학과_이준성_수시_censored.txt',
#  '202511654_1_컴퓨터과학과_이주환_정시_censored.txt',
#  '202410843_2_컴퓨터과학전공_남예린_정시_censored.txt',
#  '201611091_4학년_컴퓨터과학과_이동재_정시_censored.txt',
#  '202511468_1학년_컴퓨터과학과_이은서_정시_censored.txt',
#  '202215073_4_컴퓨터과학과_박채빈_편입_censored.txt',
#  '202511293_1학년_컴퓨터과학과_주서연_정시_censored.txt',
#  '202210133_3_컴퓨터과학전공_이채원_정시_censored.txt',
#  '202510823_1_컴퓨터과학과_위아준_수시_censored.txt',
#  '202510843_1_컴퓨터과학전공_임희철_수시_censored.txt',
#  '202511554_1_컴퓨터과학과_유재욱_정시_censored.txt',
#  '202510854_1_컴퓨터과학전공_최민규_수시_censored.txt',
#  '202111325_3학년_식품영양학과_이민재_정시_censored.txt',
#  '202511550_1_컴퓨터과학과_박지수_정시.txt',
#  '202110970_3_컴퓨터과학전공_이태훈_정시_censored.txt',
#  '202510845_1학년_컴퓨터과학과_장효석_수시_censored.txt',
#  '202510782_1_컴퓨터과학과_김동하_수시_censored.txt',
#  '202511596_1_ 컴퓨터과학과_송동준_정시_censored.txt',
#  '202510827_1학년_컴퓨터과학과_윤다인_수시_censored.txt',
#  '202511407_1학년_컴퓨터과학과_주남영_수시_censored.txt',
#  '202310098_3학년_생명공학과_김소연_정시_censored.txt',
#  '202511355_1학년_컴퓨터과학과_정지승_정시_censored.txt',
#  '202010885_3학년_컴퓨터과학과_연승혁_수시_censored.txt',
#  '202310102_3학년_컴퓨터과학과_김유빈_수시_censored.txt',
#  '202510801_1학년_컴퓨터과학과_문서진_수시_censored.txt',
#  '202211552_3_컴퓨터과학전공_임진욱_정시_censored.txt',
#  '202110937_3학년_컴퓨터과학과_서형완_수시_censored.txt',
#  '202510847_1학년_컴퓨터과학과_정윤성_수시_censored.txt',
#  '202410346_2_교육학과_성홍경_정시_censored.txt',
#  '202315049_3학년_글로벌경영학과_정유빈_수시_censored.txt',
#  '202211062_2_지능IOT_허원_정시_censored.txt',
#  '201910671_4학년_글로벌경영학과_김재욱_수시_censored.txt',
#  '202410215_2_컴퓨터과학과_이윤지_정시_censored.txt',
#  '202510818_1학년_컴퓨터과학과_성현재_수시_censored.txt',
#  '202310941_1학년_컴퓨터과학과_신성빈_정시_censored.txt',
#  '202210915_3_컴퓨터과학과_김희건_수시_censored.txt']

# %%
texts = []

for file in os.listdir("/content/records"):
    if file.endswith(".txt"):
        with open(f"/content/records/{file}", "r", encoding="utf-8") as f:
            texts.append(f.read())

len(texts)
# Out:
# 69

# %% [markdown]
# ## 1.1. 창체기록 추출

# %%
import os
import re

# Colab 세션의 기본 경로(/content)에 직접 데이터 파일들을 업로드함
TARGET_DIR = "/content/records"

# 결과를 저장할 파일 이름
OUTPUT_FILENAME = 'data.txt'

# 전체 학생 파일에서 정보를 추출하여 하나의 파일로 합치는 함수
def extract_info_and_combine(target_dir, output_filename):

    # 파일이 저장될 최종 경로 설정
    output_path = "/content/data.txt"

    # 불필요한 텍스트 제거
    unwanted_patterns = re.compile(
        r"정부24|학년|학\s*년|영역|---|Page|\* 본 증명서는 열람용이며, 법적 효력이 없습니다:|일자|창 의 적 체 험 활 동|특기사항|특기 사항",
        re.IGNORECASE
    )
    processed_count = 0

    # 디렉토리에서 파일 목록 가져오기
    try:
      files_to_process = [f for f in os.listdir(target_dir)
                    if f.endswith('.txt') and f != output_filename]
    except FileNotFoundError:
        print(f"\n⚠️ 오류: 대상 디렉토리 '{target_dir}'를 찾을 수 없습니다.")
        return

    # 결과를 저장할 파일 열기
    try:
        with open(output_path, 'w', encoding='utf-8') as outfile:

            for filename in files_to_process:

                # 파일명에서 학과, 전형 추출
                try:
                    base_name = filename[:-4]
                    parts = base_name.split('_')

                    if len(parts) >= 5:
                        학과 = parts[2]
                        전형 = parts[4]
                    else:
                        print(f"⚠️ 파일명 규칙 불일치 (건너뜀): {filename}")
                        continue

                except Exception as e:
                    print(f"⚠️ 파일명 분석 오류 발생 (건너뜀): ({filename}): {e}")
                    continue

                # 학과 이름 통일
                original_학과 = 학과

                if 학과 == "컴퓨터과학전공":
                    학과 = "컴퓨터과학과"

                # 자유전공은 계열을 명시하지 않은 학생들도 있어 하나로 통일함
                elif 학과 in ["자유전공(it계열)", "자유전공학부(인문사회계열)", "자율전공"]:
                    학과 = "자유전공학부"

                # 3. 지능IoT융합은 지능IoT로 변경
                elif 학과 in ["지능IoT융합", "지능IOT"]:
                    학과 = "지능IoT"

                # 파일 경로
                file_path = os.path.join(target_dir, filename)

                # 파일 내용 읽기
                try:
                    with open(file_path, 'r', encoding='utf-8') as infile:
                        content = infile.read()

                except Exception as e:
                    print(f"⚠️ 파일 읽기 오류 발생 (건너뜀): ({filename}): {e}")
                    continue

                # 창체기록 추출
                # 시작점: "창의적 체험활동상황", 끝점: "봉 사 활 동 실 적"
                # 창체기록 추출 (PDF → txt 변환 특성 고려)
                # '창의적 체험활동'이라는 말이 나오면 그 뒤를 전부 사용
                match = re.search(r"창의적\s*체험활동[\s\S]*", content)

                if match:
                    창체기록_raw = match.group(0)

                    # 불필요한 텍스트 제거
                    창체기록_clean = unwanted_patterns.sub('', 창체기록_raw)

                    # 공백 정리
                    창체기록 = re.sub(r'\s{2,}', ' ', 창체기록_clean).strip()
                else:
                    print(f"⚠️ 창체기록 미발견 (건너뜀): {filename}")
                    continue


                # 결과 파일에 형식에 맞게 저장
                outfile.write(f"{학과}\n")
                outfile.write(f"{전형}\n")
                outfile.write(f"{창체기록}\n")
                outfile.write("---\n")    # 각 학생 구분자

                processed_count += 1    # 처리된 파일 개수 저장

        print(f"✅ 총 {processed_count}개 파일 처리 완료")
        print(f"✅ {output_filename}파일 저장 완료")

    except Exception as e:
        print(f"\n⚠️ 치명적인 오류 발생: {e}")

# 함수 실행
extract_info_and_combine(TARGET_DIR, OUTPUT_FILENAME)
# Out:
# ✅ 총 69개 파일 처리 완료
# ✅ data.txt파일 저장 완료

# %% [markdown]
# ## 1.2. 학과, 전형 및 창체기록 키워드 추출

# %%
import pandas as pd
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# KoNLPy의 Okt 분석기
from konlpy.tag import Okt


# 파일명 설정
RAW_TEXT_FILE = 'data.txt'
OUTPUT_CSV_FILE = 'keyword_processed_data.csv'

# KoNLPy의 Okt 분석기 초기화(Okt는 명사를 추출함)
okt = Okt()

# KoNLPy의 Okt 분석기 초기화(Okt는 명사를 추출함)
okt = Okt()

# 분석에 불필요한 단어 정의(불용어)
custom_stopwords = ['년', '월', '일', '등', '것', '수', '위해', '참여', '보고서', '학년', '시간', '과정', '통해', '함께', '또한', '진로', '자신', '대한', '대해',
                    '활동', '관련', '관심', '분야', '계기', '생각', '학급', '학생', '직업', '방법', '활용', '이해', '교육', '가짐', '교내', '동안', '학교', '작성',
                    '자살', '모습', '예방', '통일', '가지', '희망', '프로', '학기', '수업', '본인', '학과', '검사', '인식']


# 데이터 추출 함수

# 태그 제거 및 공백 정리
def clean_line_tag(line):
    cleaned_line = re.sub(r'\\', '', line)
    return cleaned_line.strip()

# 학과, 전형, 창체 기록 추출
def extract_raw_data(file_path):
    students_data = []

    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            raw_text = f.read()
    except FileNotFoundError:
        print(f"⚠️ 오류: 파일을 찾을 수 없습니다: {file_path}")
        return pd.DataFrame()

    blocks = raw_text.strip().split('---')

    for i, block in enumerate(blocks):
        block_text = block.strip()
        if not block_text:
            continue

        lines = [line.strip() for line in block_text.split('\n') if line.strip()]

        if len(lines) < 3:
            continue

        original_creative_text = ' '.join(lines[2:])

        record = {
            '학과': clean_line_tag(lines[0]),
            '전형': clean_line_tag(lines[1]),
            '창체 기록_원본': original_creative_text.strip()
        }
        students_data.append(record)

    return pd.DataFrame(students_data)


# 최종 전처리 함수 (Okt 명사 추출 방식)
def preprocess_text_okt_nouns(text, analyzer, custom_stopwords):
    if not isinstance(text, str) or not text.strip():
        return ''

    # 숫자, 특수문자 제거 (명사 추출 전 수행)
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'[0-9]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()

    # Okt 분석기로 명사만 추출 (서술어 자동 제거)
    try:
        tokens = analyzer.nouns(text)
    except Exception as e:
        # Okt 분석 중 오류 발생 시 건너뜀
        print(f"⚠️ Okt 분석 중 오류 발생 (건너뜀): {e}")
        return ''

    # 필터링 (불용어 및 길이)
    final_tokens = [
        word for word in tokens
        if word not in custom_stopwords and len(word) > 1
    ]

    return ', '.join(final_tokens)

# %% [markdown]
# ## 1.3. 데이터 로드 및 정리

# %%
# !ls -l /content/data.txt
# !sed -n '1,20p' /content/data.txt
# Out:
# -rw-r--r-- 1 root root 4057118 Dec 16 12:29 /content/data.txt
# 경제금융
# 정시
# 창의적 체험활동상황 상 항 시간 장애 인식 개선 교육 (2017.03. 29. )올 통해 정신적 장애도 장애의 한 부 분임올 깨닫게 팀. 긋바이 학교폭력 예방 교육 (2017.04.19.) 시간올 통해 사이버 폭력이 통 신이 발달하면서 나타난 새로운 폭력 형태이다 이틀 경계하고 대비하기 위해 sNS 상의 게시글 작성올 조심해아켓다고 다짐함. 학급 체험의 날(2017.06. 05.)에 대한 제안서 발표에 청와대 견학올 주제 로 장소와 목적 세부 계획 필요 경비 및 기대 효과에 대해 설득력 있는 제안올 발표하여 급우늘에게 깊은 인상울 춤. 또한 ,. 실제 체험의 날 급우 늘이 정한 미선올 성실히 수행한 3인에 법힘. 성매매 예방 교육(2017.06. 14. )올 통해 성에 대한 가치관이 남자와 여자 ( 가 다을 수 있음올 알게 팀. 자살예방 및 생명 존중 교육(2017.07.21 )올 통해 힘든 상황이 되면 주변 자율활동 사람에게 도움올 청하여 위협올 극복해야 하여 고민이 부정적으로 심화 되지 암도록 주의해야 힘을 알게 팀. 수업 협약 제정 및 행복하 학급 만들기 (2017.08. 16.) 시간에 원만한 수업 분위기 형성올 위해 급우늘과 반에서 지켜야 할 사항에 대해 토의해 보다 자신의 수업 태도에 대해 점검해 보앗음. 장애 이해 교육(2017.08.23.)올 반고 자신에계는 장애우에 대해 편견이 없는 것일까에 대해 깊은 반성올 해봄. 학교 폭력 예방 교육(2017.09. 20.) 시간올 통해 욕설 , 비속어 공격적 어의 문제점에 대해 생각해 봄 학급 특색 활동 (2017.11.08. 시간에 자리블 마음대로 바뀌 앞는 것의 폐 해에 대한 의견올 발표하다 급우늘과 소통의 시간올 가짐 학급 친화 (2017.11.22. 시간에 '미리 느껴 보는 크리스마스' 활동에 적 극적으로 참여하여 나무젓가락올 이용하여 썰매블 끄는 루돌프 소품올 만 4 창 의 직 체 헌 활 동상 항 시간 늘어 전시하여 , 급우늘과 함께하는 시간의 소중함올 느낌 (교지편집반) ( 37 시간) 교지 대소리 제작올 위해 기획 회의에 주도직으로 참여하고 주제 발국에 창의적인 의견올 제시햇으다, 원고 청탁과 취합 및 편집과 고정 작업에 참여합. 영어말하기대회와 현혈 봉사 활동올 취재하 동아리활동 38 여 기사을 작성하여 기고함. (1-4축구 방과후학교스포츠클럽) (1시간) 학생 -학부모 연합 봉사활동 동아리 '사프론-창신' 
, 주기 등에 길 친 다양한 도시 문제블 도출햇으미 IT 기술이 해당 문제블 어명게 해결할 수 있는지 이해하여 가상의 도시 설계 프로제트블 진행합 . 과학 원리블 실생활에 적용해 기술적 해결칙올 제공하는 공학의 가치와 필요성올 깊이 깨달아 해당 분아에도 관심올 갖게 희망 진로가 바뀌없지만 자신에게 필요한 역량울 꾸준히 담구하다 노력하는 모습이 인 상적인 학생임 4 창 의 직 체 험 활 동 상 화 시간 학급에서 진행볕 학급 회의에 적극적으로 참여하여 교훈 학급 규칙에 대한 아이디어 틀 제시하고 학급에서 제시된 여러 아이디어블 논의하는 민주직인 도의에 참여하여 학급의 1년 방향울 수립하는데 기여합 . 창체 영화 수업올 이수하엿고 스마드포올 이용하 영상울 기획 및 촬영함 . 팀별 제작 실 숨에서 유비 <피에스타>의 기획에 참여하고 팀장과 배우블 맡아 팀원올 이골고 기획에 자율활동 75 참여함. 그 결과 작품올 완성 , 제출하고 상영함. 소규모테마형 교육여행 (2022.10.12. -2022.10. 14. )에 참여하여 학급 친구늘과 생활 하여 서로 배려하는 태도물 기르고 공동체 의식올 합양하는 시간올 가짐 . 또한 볼입형 미디어아트 전시블 관광하다 예술의 다양한 표현 방식올 접하여 예술적 시각올 넓질 수 있는 기회블 가져고 제주도에 오름이 형성된 원인에 대해 알아본 뒤 직접 오름올 오르며 자연올 느끼고 체력 증진올 함. 이외에 다양하 체험올 하머 함께 하는 것의 줄 거움 현동심에 대해 깨닫는 모습올 보임. (바이오키미 (생 불화학동아리) ) (26 시간) 생명과학 . 화학 관련 스크램 활동에서 '알추히 이머 , 효과적인 치료 가능한가? '라는 주제로 포드플리오응 제작하여 년하이드린 용액 올 분사해 지문채 취틀 하는 이체법올 상세하게 다툼. 적절한 온도와 습도에서 년하이 드린이 아미노기와 탈수반응해 루히만 퍼풀이 생성되고 에너지 준위차에 의해 보라색 빛의 가시광선이 방출되어 우리 눈에 지문이 다른 색으로 구분되어 나타나는 과학 수 사 기법올 단계적으로 설명하고, 고난이도의 양자화학적 원리블 이해햇음올 알 수 잎 동아리활동 26 다양한 실험 담구 활동에 적극적으로 참여하고 , 실험 결과블 해석하는데 흥미블 찾 눈 열정적인 학생임 . 여러가지 화학결합 중 수소결합올 담구 후 불이 표면장력 올 활용 해 클럽올 가장 많이 띄우는데 성공함 . 혈액형 판정 실험 활동에서는 인체 내 면역체계 틀 명확하게 이해하고 배신올 설계하기 어려운 병원체로 에이즈 혈우병올 늘고 직혈 모구증올 해결할 방법으로 로감주사와 그 원리블 설명하는 보고서블 제출함 . 멘도스와 콜라로 폭발올 일으키는 실험에서 적극적으로 멘도스블 설치하는 방안에 대해 고안하 고, 압력과 표면적과 관련된 과학 원리블 스스로 유추해 친구늘에게 설명하는 역량울 선보임. 5 창 의 직 체 험 활 동 상 화 시간 희망분야 약학 1년 동안 학급에서 진행한 '진로 포드플리오 '에 참여하여 진로에 대해 고민하는 시간올 가지고 약학 분야에 대한 자료틀 다방면으로 탄색함 . 약사가 하는 일에 대한 영상울 시청 후 본인의 
# ---
# 컴퓨터과학과
# 수시
# 창의적 체험활동상황 창 의 직 체 험 활 동 상 항 시간 3 상 항 시간 과학의 달올 맞아 개최한 '과학 한마당 (2021,04.30.) ' 행사에 참여하여 , 통합과학 시 간에 배운 생명체름 구성하는 단소 화합물인 단백질과 핵산올 구성하는 원소의 종류의 화학결합 형태름 이미지화하여 '단소 화합물 '이관 용어름 과학용어 문자도로 표현함. 1학기 '목표성 취환동(2021.04.05. 2021.06.25.) '과 2학기 '목표성 취활동(2021.09. 06-2021.12.03.) '에 참여하여 '매일 수학 문제 풀고 오답 정리하기' , '주 3회 과학 관 권 기사 찾아 읽고 보고서 작성하기' 의 목표록 달성하엿으미 자신과의 약속올 지켜 나 자율활동 가능 모습올 통해 과제에 대한 집작력과 인내심올 확인할 수 있있음. '소프트웨어 엔지니어 직업인 특강 (2021.11.03.) '에 참여하여 우리의 언어률 컴퓨터 언어로 번역하는 과정올 담색함 . 특히 프로그래머의 다양한 분야 중 본인에계 맛는 진 로에 대해 더 자세히 조사해 보고 프로그래망 언어률 배우객다는 다짐올 밝힘 . '나숙과 배려의 수학 . 과학제 (2021.11.26.) '에 참가하여 '다퓨저 만들기 , '산염기 라바 램프 만들기' 부스 체험올 통해 교과 시간에 배운 과학적 개념을 직접 실험올 하여 재 현해 보고, 실험 결과와 활동 후 느낌 점 등올 기록하여 활동 보고서름 제출함. (피스트리반) (26시간) 과학에 대한 흥미와 호기심울 바탕으로 동아리에 지원하여 높은 관심올 갖고 실험에 참여하는 모습이 보이다, 제백효과 실험에서논 멀티테스터기의 놓아리활동 26 다양한 활용법올 새롭게 알게 뇌면서 실생활에 활용하는 방법에 대해 고민함 . 제백호 과 실험에서 기전력이 나타나는 원리률 담구해보면서 금속과 전류의 흐름에 대해 생각 해보는 계기가 팀 . 브리스 라우서 실험올 통해 과학에 대한 관심과 흥미가 높아져으녀 실험 과정올 짜임새 앞게 잘 정리하는 모습올 보임. 4 상 항 시간 희망분야 컴퓨터. 소프트웨어. 정보통신기술 . 인공지능 분야 '학과멘토랑 (2021.05.17.-2021.05.18,) ' 활동에 참여하여 휴먼지능정보학과는 인공 지능 데이터 관련 학과로서 프로그래망을 위주로 한다는 젊이 컴퓨터공학과와 다르다 논 것울 알게 되있다는 점은 발표함 . 용용통계학과는 넥데이터 정보통신기술 , 금움관 련 분야 등 응용통계가 필요한 다양한 분야의 진로로 나아갈 수 있다는 것울 알게 되엇 여러 학과 담색으로 본인의 진로름 설정하는데 많은 도움이 되있다는 소감을 밝 '관심 분야 조사하여 발표하기' 활동에서 핑소 좋아하는 인공지능 코당과 감은 컴퓨터 분야와 언계하여 '메타버스' 에 관해 조사한 내용올 발표함 . 온라인 게임음 예로 제시하 며 메타버스름 이해하기 쉽계 설명하없고 , 나이 , 국적 등의 선입견 없이 다양한 사람들 진로활동 34 과 만날 수 있다는 메타버스의 장점올 소개함. 앞으로 다양한 분아에서 메타버스가 상 용화월 것이미, 그 안에서의 규칙들이 생겨나면서 우리의 삶에 임청난 영향울 끼칠 것 이라 전망함 . '배율동행멘토랑 (2021.09.06-2021.12.17.) ' 활동에 과학 과목의 멘토로 참여하여 원리 학습과 적용 연습올 하머 학습 여량울 강화함. '직업 담색' 활동에서 핑소 관심이 있단 공학계 열과 관련하이 가상현실 전문가라는 직 업에 대해 담색해 봄 . 새로운 세계름 창조해 벌 수 있다는 점이 근 매력으로 다가앉다 논 소감을 밝히다 후에 메타버스 , 게임 프로그램에 대해 더 조사함. 진로 독서 시간에 '기의 모든 IT의 역사' 틀 읽고 소감문올 작성하이 발표함. 교육청이 주최하고 주관한 1학기 경기꿈의대학 (데이터와 인공지능) 17시간을 이수함 . 교육청이 주최하고 주관한 2학기 경기품의대학 (문제해결올 위한 알고리증과 파이씬 프 로그래망) 17시간을 이수함 으머 5 상 항 시간 학급 자율 성장 프로직트 도시락 환동(2022.03.11. -2022.12.16.)에서 학급에서 이 립진 다양한 활동에 참여함 . 마니도 주간에 여할을 잘 수행하여 친밀감을 형성하없으 며 타인에 대한 배러심이 돕보임. 1학기 배율동행멘트랑에 물리 교과의 벤토로서 맨티인 학생이 학업적으로 발달올 할 수 있기 도움올 주없으며 함께 하는 학습음 통하여 협동심과 배러심올 함양함 . 친구름 알리주기 위한 책임감올 가져 자기 주도적인 학습태도틀 지니게 되는 게기가 팀. 나늄과 배리의 수학과학제 (2022.10.28 )에 참가하여 교과 시간에 배운 수학 과학적 자율환동 개념과 원리에 바탕을 눈 실험 및 담구 활동 부스 '한봇그리기름 이용하 네온사인 제작' 에서 기구름 조작하고 모형 만들기 등올 직접 체험하고 이해한 내용과 활동 소감을 기 록한 담구 활동 보고서름 제출함 . 2학기 목표성 취활동에서 '진로 관련된 책올 계획적으로 읽고 요약하기' 라는 목표름 설 정하고 달성함. '미래틀 바군 아흡 가지 알고리롬 '올 계획한 대로 읽고 주요 내용올 징 리하머 컴퓨터 , IT분아에 필수적인 알고리금에 대하여 자세히 접하는 계기가 팀. 활동 올 통해 진로와 관련된 책올 읽고 지식올 함양할 수 있어서 꿈과 가까워질 수 있있다고 소감을 밝힘 (피스트리) (24시간) 매번 실험올 성실히 수행하고 실험 원리 , 실험 방법 , 결과 분석 추가 자료 조사름 꼼꼼하게 작성하여 제출하는 학생임. 진로 특강 (전기공학 , 그 무한의 바다) 에서 전기공학이 전기에 관련된 일만 하는 줄 알앞는데 전기분만 아니라 전자, 정보 통신 , IT , 소프트웨어 , 인공지능 소프트웨어 등 다양한 분야률 아우로고 있는 폭넓은 학문 임을 알게 되있다는 활동 보고서름 작성하여 제출함. 진로 특강 (넥데이터에 대한 이해) 에서 넥데이터의 개념, 용용분야 , 역랑에 대해 강의름 동아리활동 24 들으다 넥데이터라는 분야가 나중에 생기난 분야가 아니라 과거에도 기록되며 사용뇌 엿다는 사실올 새롭게 알게 되엇고 . 단순히 넥데이터가 통계 분야변만 아니라 의료나 공학 분야 등 다양한 분아에서 활용되고 있고, 우리 일상 생활에도 근 도움올 준다는 점에서 흥미롭게 다가앉다는 활동 보고서름 작성함. 공공기관 협력 실험 발표에서 '드론 만들기' 부스름 운영함 예비 실험에 성실하게 참여 하여고 체험 학생들인 조등학교 저생들의 눈높이에 맛게 알기 실계 설명함 . 예비 실험에서는 성공하지 못햇으나 원인올 과학적으로 분석하여 발표 당일에는 성공하여 뿌듯함올 느껴다는 활동 보고서름 제출함. 6 상 항 시간 희망분야 컴퓨터 공학 , 인공지능 계열 최근 IT 인공지능에 대한 관심이 커저 소프트웨어에 대한 내용올 깊이 앞게 담구하여 진로 프레센테이선올 실시함 . 청중올 사로잡는 가독성 있는 발표 자료름 바탕으로 적 절한 발성과 안정감 있는 어조로 시스템 소프트웨어와 응용 소프트웨어로 구분하여 소 프트웨어의 종류에 대해 구체적으로 설명하여 청중들의 이해름 도움. 또한 , 소프트웨 어와 관련된 및 전망을 소개하다 이와 관련된 진로름 준비하기 위해서는 컴퓨터 및 전자공학 지식 , 분석적 사고 능력 전산 능력 , 4차 산업 도구 및 기술의 환용 능력이 필요하다는 점은 강조하다 이외 같은 여량울 갖추고자 하는 자신의 포부름 발표함. '대학 학과 전공 체험 ' 의 산업경영 정보공학 전공에 참여함 IT와 관련하여 소프트웨어 개발 분야만 생각햇엿는데 학과 체험올 통해 4차 산입 시대에 맛게 다양한 학문과 음 진로활동 합원 학문올 공부하는 것에도 관심을 가지는 계기가 팀 . '아두이노 환용 스마트 로봇 만들기' 과정에 참여함 . 아두이노 판과 컴퓨터름 연결하여 프로그래망 후 아두이노 판에 전송하면 그것올 토대로 스마트 로봇이 움직인다는 것에 흥미름 느낌. 사용 목적에 따라 다양한 종류의 아두이노 판이 이용되다는 것을 알계 되 엿으머 직접 코딩해서 로봇올 움직여 보미 프로그래망의 새로운 분야름 경험해 보게 뇌 어 진로 선택의 폭올 넓히게 되는 계기가 팀 . 전공 체험 후 아두이노의 쓰임에 대해 더 알아봄. 컴퓨터공학과 업무 관련성올 알아보고자 '직업인 특강-넥데이터 전문가' 에 참여함 . 데이터틀 이용한 기술이 더욱 발달함에 따라서 중요해지고 있음올 알게 팀 . 넥데이터 논 A[틀 만드는 ...
# ---
# 컴퓨터과학과
# 정시
# 창의적 체험활동상황 대접화인 2 창의 직체 험 활 동상 황 시간 학교특색활동 -인 1과제 담구 프로적트 (학술 및 진로 , 특기적성 관련 심화학습, 1학기 1단 위 2학기 1단위) 이수. 특색수입인 '1인 1과제 담구' 환동에서 '공학의 역사와 미래 비전 올 주제로 정함. 이 과정올 통해 공학이라는 학문의 역사와 역할에 대해 조사하고 고민하는 시간을 가짐. 공학이 다른 분 아외의 음합올 통해 더 나은 기술이 볼 수 있음올 깨달앗으미 자신도 공학에 대해 더 열린 자 세틀 가져아켓다고 생각함. 휴연 폐해 및 예방대책 (06. 11)올 듣고 훈연의 심각성에 대해서 알게 되없고, 주변의 훈연자들 자율활동 에계 금연올 권고함 심페소생술교육(10.08 )올 통해 주변에 심정지가 일어난 사람이 생기면 어떻계 대처해야 하 논 지 배우게 팀. 심패소생술은 자신과 주변인의 생명올 지길 수 있는 중요한 기술이므로 모 두가 숙지하고 어떤 상황이튼 함 수 있도록 훈련되어야함을 느낌. 학교폭력예방교육 및 토의(10.22 )틀 통해 학교폭력으로 고통 받는 친구들의 고통올 조금이 나마 이해하게 팀. 학교 폭력에 어떻게 대응해야 하느지 예방울 위해서논 무엇을 해야 하는 지에 대해 알게 팀 (DSLR (사진반)) (34시간) 놓아리 부회장(2021.03.01. -2022.02.28,) 으로 리더십올 가지고 동아리률 탁월하게 이골고 심기는 모습이 중앞으며 풍경 사진올 좋아하다 구도록 잡율 때 놓아리활동 34 여백의 미름 좋아해 찍고자 하는 주제에 집중노률 높여p. 건축관련 사진에 관심이 많아서 다 양한 건물 사진 찍기루 좋아하고 건물의 선이 잘 드러나도록 사진의 구도도 잘 집는 편임. 매 시간 활동에 적극적으로 참여함하고, 원거리 사진에 대해 질문올 많이 함 흘랜드 흥미검사 다중지능 적성검사 MBTI 성격검사. 직업 가치관 김사물 실시하없으미 이날 통해 자신의 자아정체성 및 직업적성올 인식함. 또한 다양한 직업올 분석하고 자신에게 적합한 진로 경로 및 비전올 찾기 위해 노력함. 교내에서 실시한 전공흥미검사 (2021.11.05 ) 결과 해당 전공과 연관된 직무활동과 직업에 대 한 선호도물 고려할 때 전기 . 전자 . 컴퓨터, 기계 . 조선 . 항공 , 화공 . 재료에 가장 많은 흥미 진로활동 36 풀 보이는 것으로 나타남. 1순위인 전기 . 전자 . 컴퓨터 전공은 여러 공학 분아의 기본으로 인 간의 삶올 편리하게 해 주년 전자 및 컴퓨터 기기블 만드는 방법올 공부하는 학문으로 본인 이 선호하는 활동과 직업올 고려햇올 때 가장 관련성이 높은 전공임. 또한 선호직무유형은 연 구자형으로 , 지식 혹은 이론의 확특이나 정립올 목적으로 자료플 수집 및 조사, 분석 검토하 눈 활동올 선호함. 검사 결과을 봉해 진로에 대한 현화올 전반적으로 점검하고, 부족한 부분 올 보완할 수 있도록 함. #특색수업 (아두이노) 1학기 1단위 이수 2학기 1단위 이수(1학기 (2022.03.07.-2022.07.0 8,) 특색 수업인 아두이노 고딩 시간에 아두이노 온 습도 표시기 제작 활동에서 성실하게 제 작울 마무리하없으머, 온습도 센서 값 확인하기 온습도 센서 표시기 작업까지 잘 마무리함. 자율활동 67 2학기(2022,09.05 -2022.12.02,) 특색 수업인 AI 프로그래망 시간에 하드웨어에 해당하 눈 입출력 부품올 코드로 제어하는 코딩 과정에서 프로그램올 구현하는 과정 및 컴퓨터언어 의 흐름(로직) 올 이해하고 응용할 수 있음. 파이씬에 대해 충분히 이해함 ) 3 창의 직체 험 활 동상 황 시간 약물오남용예방교육(2022.04.22 )올 통해 잘못된 약물복용에 따른 부작용의 폐해 및 약물 올 올바르게 사용하는 방법 등올 배우고 평소 약물예 대한 궁금증올 질문올 통해 해결합 수 있는 유의한 시간을 가짐,
 실 적 또는 기간 장소 또는 주관기관명 활동내용 시간 2021.03.05. (학교) 강서고등학교 봉사 (봉사활동 기초교육) 2021,06.18. (학교) 강서고등학교 봉사 (장애인식 개선교육) 2021.09.10. (학교) 강서고등학교 자원순환 활동교육 및 캠페인 활동 2021.09.24, (학교) 강서고등학교 봉사 (봉사활동 심화교육) 2021.11.26. (학교) 강서고등학교 봉사 (장애인식 개선교육) 2022.03.04. (학교) 강서고등학교 봉사활동 기초교육 2022.06.24. (학교) 강서고등학교 봉사활동 심화교육 2022.10.14 (학교) 강서고등학교 봉사학습과 진로 2022.11.11. (학교) 강서고등학교 장애인식 개선교육 2023.03.03. (학교) 강서고등학교 봉사활동 기초교육 2023.05.19. (학교) 강서고등학교 봉사활동과 리더심 2023.06.23. (학교) 강서고등학교 봉사활동 심화교육 교과학습발달상황 [1] 원점수 / 과목평균 성취도 학기 교과 과목 단위수 석차등급 (표준편차) (수강자수) 국어 국어 69/70.5(12.7) (327) 수학 수학 69/65.6(16. 3) (327) 영어 영어 32/70.8(22.2) (327) 한국사 한국사 43/54.3(20.6) (327) 사회 ...
# ---

# %%
data_df = extract_raw_data(RAW_TEXT_FILE)

if data_df.empty:
    raise Exception("⚠️ 데이터 로드 실패. 파일 경로 및 형식을 확인하세요.")

print(f"✅ 총 {len(data_df)}명의 학생 데이터 로드 완료")

# 결측값 및 공백 값 정리
data_df['창체 기록_원본'] = data_df['창체 기록_원본'].fillna('')
data_df = data_df[data_df['창체 기록_원본'].str.strip().str.len() > 0].copy()

print(f"✅ 데이터 정리 완료. 최종 데이터 행 수: {len(data_df)}")

# 상위 5개 행 출력(확인용)
print(data_df.head())
# Out:
# ✅ 총 69명의 학생 데이터 로드 완료
# ✅ 데이터 정리 완료. 최종 데이터 행 수: 69
#         학과  전형                                           창체 기록_원본
# 0     경제금융  정시  창의적 체험활동상황 상 항 시간 장애 인식 개선 교육 (2017.03. 29. )올...
# 1   자유전공학부  정시  창의적 체험활동상황 상 화 시간 학급 부회장 (2021.03.02. 2021.08....
# 2  글로벌경영학과  정시  창의적 체험활동상황 창 의 적 체 힘 활 동 상 화 시간 청소년 생명존중 프로그램인...
# 3   컴퓨터과학과  수시  창의적 체험활동상황 창 의 직 체 험 활 동 상 항 시간 3 상 항 시간 과학의 달...
# 4   컴퓨터과학과  정시  창의적 체험활동상황 대접화인 2 창의 직체 험 활 동상 황 시간 학교특색활동 -인 ...

# %% [markdown]
# ## 1.4. 전처리 적용 및 명사 리스트 컬럼 생성

# %%
# Okt 분석기, 불용어 리스트 사용하여 전처리 적용
data_df['명사 리스트'] = data_df['창체 기록_원본'].apply(
    lambda x: preprocess_text_okt_nouns(x, okt, custom_stopwords))

print("✅ 전처리 완료")

#상위 5개 행 출력(확인용)
print(data_df[['학과', '전형', '명사 리스트']].head())

# %% [markdown]
# ## 1.5. 최종 결과 CSV파일로 저장

# %%
data_df.to_csv(OUTPUT_CSV_FILE, index=False, encoding='utf-8-sig')

print(f"\n✅ '{OUTPUT_CSV_FILE}' 파일 저장 완료")

# %% [markdown]
# # **2. 키워드 빈도 분석 (wordcloud)**
# * 전체 및 학과, 전형 별 워드 클라우드 생성
# * 주요 키워드(상위 10개) 개수 출력
# * 학과별 워드 클라우드에서 컴퓨터과학과가 가장 먼저 출력되도록 함
# * 학과별, 전형별 워드 클라우드에서 캔버스가 2개씩 출력되며 각 캔버스 밑에 개수가 출력되도록 함

# %% [markdown]
# ## 2.1. 데이터 파일 로드

# %%
import matplotlib.font_manager as fm
import pandas as pd

# 폰트 지정
FONT_PATH = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# 저장된 파일 이름 확인
INPUT_CSV_FILE = 'keyword_processed_data.csv'

# 전처리 완료된 CSV 파일 로드
analysis_df = pd.read_csv(INPUT_CSV_FILE, encoding='utf-8-sig')

# 폰트 속성 객체 생성 (제목 깨짐 방지용)
title_font_prop = fm.FontProperties(fname=FONT_PATH, size=18)

# %% [markdown]
# ## 2.2. 키워드 개수 계산 및 출력 함수

# %%
# 상위 10개 키워드 개수 계산 및 출력 함수
from collections import Counter
import math
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

def keyword_counts(group_name, text_data):
    if not text_data.strip():
        return {
            'major': group_name,
            'keywords': ["키워드 데이터가 비어 있습니다."]
        }

    # 텍스트 데이터를 공백 기준으로 토큰화하고 빈도 계산
    tokens = text_data.split(' ')
    word_counts = Counter(tokens)

    # 공백 토큰 제거
    if '' in word_counts:
        del word_counts['']

    top_10 = word_counts.most_common(10)

    # 학과명과 키워드 목록을 딕셔너리로 반환
    return {
        'major': group_name,
        'keywords': [f"{keyword}: {count}개" for keyword, count in top_10]
    }


# 주요 키워드 목록 출력 위치 지정 함수
def plot_keywords_on_axis(keywords_list, ax_text, font_prop, font_size=14):
    header = "[주요 키워드 개수]"
    text_content = header + "\n" + "\n".join(keywords_list)

    # 텍스트 영역에 주요 키워드 개수 출력
    ax_text.text(
        0.0, 0.95,
        text_content,
        transform=ax_text.transAxes,
        fontproperties=font_prop,
        fontsize=font_size,
        verticalalignment='top',
        horizontalalignment='left',
        color='black'
    )
    ax_text.axis('off') # 축 숨기기

# %% [markdown]
# ## 2.3. 워드 클라우드 시각화

# %% [markdown]
# ### 2.3.1. 전체 워드 클라우드

# %%
# 워드 클라우드 시각화
# 전체 워드 클라우드

all_words = ' '.join(analysis_df['명사 리스트'].str.replace(',', ' ').dropna())

wc = WordCloud(
    font_path=FONT_PATH,
    width=1000,
    height=600,
    background_color='white',
    max_words=100,
    prefer_horizontal=0.9
)
wordcloud = wc.generate(all_words)

# 키워드 데이터 추출
result = keyword_counts("전체 분석", all_words)
keywords_list = result['keywords']

# 캔버스와 GridSpec 설정
fig = plt.figure(figsize=(9, 8))
gs_main = GridSpec(1, 1, figure=fig)

# 중첩 GridSpec 생성(워드 클라우드와 텍스트가 겹치지 않도록 분리)
gs_nested = gs_main[0].subgridspec(10, 1, hspace=0.1)

ax_wc = fig.add_subplot(gs_nested[0:8, 0])  # 워드 클라우드 영역 (상단 80%)
ax_text = fig.add_subplot(gs_nested[8:10, 0]) # 텍스트 영역 (하단 20%)

# 워드 클라우드 시각화
ax_wc.imshow(wordcloud, interpolation='bilinear')
ax_wc.axis('off')
ax_wc.set_title("전체 핵심 키워드 분석", fontproperties=title_font_prop)

# 키워드 개수 출력
plot_keywords_on_axis(keywords_list, ax_text, title_font_prop, font_size=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3.2. 학과별 워드 클라우드

# %%
# 학과별 워드 클라우드
grouped_data = analysis_df.groupby('학과')['명사 리스트'].apply(
    lambda x: ' '.join(x.str.replace(',', ' ').dropna())
)

# 컴퓨터과학과가 가장 먼저 출력되도록 지정
TARGET_MAJOR = '컴퓨터과학과'
ordered_data = []

# 컴퓨터과학과 데이터 추출 및 맨 앞에 추가
if TARGET_MAJOR in grouped_data:
    ordered_data.append((TARGET_MAJOR, grouped_data[TARGET_MAJOR]))

    # 나머지 학과 데이터 추가
    remaining_items = [(major, text)
                       for major, text in grouped_data.items()
                       if major != TARGET_MAJOR]
    ordered_data.extend(remaining_items)
else:
    ordered_data = list(grouped_data.items())

num_groups = len(ordered_data)
MAX_COLS = 2 # 각 행에 캔버스 2개씩 출력

# 그룹화된 데이터가 있을 경우 시각화 진행
if num_groups > 0:
    # 총 필요한 행 수 계산
    nrows = math.ceil(num_groups / MAX_COLS)
    fig = plt.figure(figsize=(6 * MAX_COLS, 8.5 * nrows))

    # 메인 GridSpec 생성
    gs_main = GridSpec(nrows, MAX_COLS, figure=fig)

    # 워드 클라우드 생성
    # ordered_data 순회 (정해진 순서대로 순회)
    for i, (major, text) in enumerate(ordered_data):

        # 현재 학과가 들어갈 위치 계산
        row_idx = i // MAX_COLS
        col_idx = i % MAX_COLS

        # 해당 위치에 중첩 GridSpec 생성(워드클라우드와 텍스트가 겹치지 않도록 함)
        gs_nested = gs_main[row_idx, col_idx].subgridspec(10, 1, hspace=0.1)

        # 서브 영역 할당
        ax_wc = fig.add_subplot(gs_nested[0:8, 0])  # 워드 클라우드 영역 (상단 80%)
        ax_text = fig.add_subplot(gs_nested[8:10, 0]) # 키워드 텍스트 영역 (하단 20%)

        # 워드 클라우드 및 데이터 처리
        result = keyword_counts(major, text)
        keywords_list = result['keywords']

        wc_major = WordCloud(
            font_path=FONT_PATH,
            width=800,
            height=800,
            background_color='white',
            max_words=50
        )
        wordcloud_major = wc_major.generate(text)

        # 워드 클라우드 시각화
        ax_wc.imshow(wordcloud_major, interpolation='bilinear')
        ax_wc.axis('off')
        ax_wc.set_title(f"학과: {major}", fontproperties=title_font_prop)

        # 주요 키워드 개수 출력
        plot_keywords_on_axis(keywords_list, ax_text, title_font_prop, font_size=14)

    plt.tight_layout()
    plt.show()

else:
    print("\n학과별 그룹화할 데이터가 충분하지 않습니다.")

# %% [markdown]
# ### 2.3.3. 전형별 워드 클라우드

# %%
# 전형별 워드 클라우드
grouped_data2 = analysis_df.groupby('전형')['명사 리스트'].apply(
    lambda x: ' '.join(x.str.replace(',', ' ').dropna())
)
num_groups = len(grouped_data2)
MAX_COLS = 2 # 각 행에 캔버스 2개씩 출력

if num_groups > 0:

    # 총 필요한 행 수 계산
    nrows = math.ceil(num_groups / MAX_COLS)
    fig = plt.figure(figsize=(6 * MAX_COLS, 8.5 * nrows))

    # 메인 GridSpec 생성
    gs_main = GridSpec(nrows, MAX_COLS, figure=fig)

    # 전형별 워드 클라우드 생성
    for i, (type, text) in enumerate(grouped_data2.items()):

        # 현재 전형이 들어갈 위치 계산
        row_idx = i // MAX_COLS
        col_idx = i % MAX_COLS

        # 해당 위치에 중첩 GridSpec 생성
        gs_nested = gs_main[row_idx, col_idx].subgridspec(10, 1, hspace=0.1)

        # 서브 영역 할당
        ax_wc = fig.add_subplot(gs_nested[0:8, 0]) # 워드 클라우드 영역
        ax_text = fig.add_subplot(gs_nested[8:10, 0]) # 텍스트 영역

        # 워드 클라우드 및 데이터 처리
        result = keyword_counts(type, text)
        keywords_list = result['keywords']

        wc_type = WordCloud(
            font_path=FONT_PATH,
            width=800,
            height=800,
            background_color='white',
            max_words=50
        )
        wordcloud_type = wc_type.generate(text)

        # 워드 클라우드 시각화
        ax_wc.imshow(wordcloud_type, interpolation='bilinear')
        ax_wc.axis('off')
        ax_wc.set_title(f"전형: {type}", fontproperties=title_font_prop)

        # 주요 키워드 개수 출력
        plot_keywords_on_axis(keywords_list, ax_text, title_font_prop, font_size=14)

    plt.tight_layout()
    plt.show()

else:
    print("\n'전형'별 그룹화할 데이터가 충분하지 않습니다.")

# %% [markdown]
# # **3. 키워드 유사성 분포 분석(PCA)**
# *   유사한 키워드들이 이루는 군집을 분석함
# *   TF-IDF를 이용해 키워드 중요도를 계산하고, 이를 이용하여 유사성을 판단함
# *   그래프에서 두 점이 가까울수록 그 학생들은 키워드 유사성이 높다고 해석할 수 있음

# %% [markdown]
# ## 3.1. 키워드 중요도 계산 및 PCA 수행

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

INPUT_CSV_FILE = 'keyword_processed_data.csv'
FONT_PATH = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'


# 한글 깨짐 방지 폰트 설정
font_name = fm.FontProperties(fname=FONT_PATH).get_name()
plt.rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False
title_font_prop = fm.FontProperties(fname=FONT_PATH, size=16)

# 전처리 완료된 CSV 파일 로드
try:
    analysis_df = pd.read_csv(INPUT_CSV_FILE, encoding='utf-8-sig')
    analysis_df['명사 리스트'] = analysis_df['명사 리스트'].fillna('')
    analysis_df = analysis_df[analysis_df['명사 리스트'].str.strip().str.len() > 0].copy()
    N = len(analysis_df)
except FileNotFoundError:
    print(f"오류: '{INPUT_CSV_FILE}' 파일을 찾을 수 없습니다.")
    exit()

# TF-IDF 벡터화
tfidf_vectorizer = TfidfVectorizer(max_features=300, token_pattern=r'\b\w+\b')
documents = analysis_df['명사 리스트'].str.replace(', ', ' ').tolist()
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

# PCA를 위해 희소 행렬을 밀집 행렬로 변환
tfidf_array = tfidf_matrix.toarray()
print(f"✅ TF-IDF 벡터 차원: {tfidf_array.shape}")

# PCA 수행
# 주성분 2개로 차원 축소
pca = PCA(n_components=2)

# PCA 모델 학습 및 데이터 변환
pca_results = pca.fit_transform(tfidf_array)

# PCA 결과를 DataFrame으로 정리
pca_df = pd.DataFrame(data=pca_results, columns=['Principal Component 1', 'Principal Component 2'])
# 학과 및 전형 정보 병합 (시각화 색상 구분 위해)
pca_df = pd.concat([pca_df, analysis_df[['학과', '전형']].reset_index(drop=True)], axis=1)

print(f"✅ PCA 완료. 총 분산 설명률: {pca.explained_variance_ratio_.sum()*100:.2f}%")

# %% [markdown]
# ## 3.2. PCA 시각화

# %% [markdown]
# ### 3.2.1. 학과별 키워드 유사성 분포

# %%
# 컴퓨터과학과와 그 외 학과를 구분함
pca_df['학과 구분'] = pca_df['학과'].apply(lambda x: '컴퓨터과학과' if x == '컴퓨터과학과' else '그 외 학과')

plt.figure(figsize=(10, 8))

# '학과 구분'을 기준으로 산점도 생성
sns.scatterplot(
    x='Principal Component 1',
    y='Principal Component 2',
    hue='학과 구분',
    data=pca_df,
    s=150,
    alpha=0.8
)

plt.title('키워드 유사성에 따른 학생 분포 (학과)', fontproperties=title_font_prop)
plt.xlabel(f'주성분 1 ({pca.explained_variance_ratio_[0]*100:.2f}%)', fontproperties=title_font_prop)
plt.ylabel(f'주성분 2 ({pca.explained_variance_ratio_[1]*100:.2f}%)', fontproperties=title_font_prop)

# 범례
legend = plt.legend(title='학과 구분', loc='best')
plt.setp(legend.get_title(), fontproperties=title_font_prop)
for text in legend.get_texts():
    text.set_font_properties(fm.FontProperties(fname=FONT_PATH, size=12))

plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### 3.2.2. 전형별 키워드 유사성 분포

# %%
plt.figure(figsize=(10, 8))

# '전형'을 기준으로 산점도 생성
sns.scatterplot(
    x='Principal Component 1',
    y='Principal Component 2',
    hue='전형',
    data=pca_df,
    s=150,
    alpha=0.8
)

plt.title('키워드 유사성에 따른 학생 분포 (전형)', fontproperties=title_font_prop)
plt.xlabel(f'주성분 1 ({pca.explained_variance_ratio_[0]*100:.2f}%)', fontproperties=title_font_prop)
plt.ylabel(f'주성분 2 ({pca.explained_variance_ratio_[1]*100:.2f}%)', fontproperties=title_font_prop)

# 범례
legend = plt.legend(title='전형', loc='best')
plt.setp(legend.get_title(), fontproperties=title_font_prop)
for text in legend.get_texts():
    text.set_font_properties(fm.FontProperties(fname=FONT_PATH, size=12))

plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### 3.2.3. 학과 및 전형별 키워드 유사성 분포

# %%
# 전형과 학과 구분을 결합한 새로운 컬럼 생성
pca_df['전형_학과'] = pca_df['전형'] + '_' + pca_df['학과 구분']

plt.figure(figsize=(10, 8))
# '전형_학과'를 기준으로 산점도 생성
sns.scatterplot(
    x='Principal Component 1',
    y='Principal Component 2',
    hue='전형_학과',
    data=pca_df,
    s=150,
    alpha=0.8
)

plt.title('키워드 유사성에 따른 학생 분포 (학과+전형)', fontproperties=title_font_prop)
plt.xlabel(f'주성분 1 ({pca.explained_variance_ratio_[0]*100:.2f}%)', fontproperties=title_font_prop)
plt.ylabel(f'주성분 2 ({pca.explained_variance_ratio_[1]*100:.2f}%)', fontproperties=title_font_prop)

# 범례
legend = plt.legend(title='전형 및 학과', loc='best')
plt.setp(legend.get_title(), fontproperties=title_font_prop)
for text in legend.get_texts():
    text.set_font_properties(fm.FontProperties(fname=FONT_PATH, size=12))

plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
